# %% [markdown]
# ## Extracting article url info from ESPN

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
def pprint(soup):# pretty print
    print(soup.prettify())

# %%
html_page =  requests.get("http://www.espn.com/nfl/team/_/name/buf/buffalo-bills")
soup = BeautifulSoup(html_page.content, 'lxml')

# %%
# we know that all article links are in the 'article' tag
articles = [art for art in soup.find_all('article') if 'data-id' in art.attrs.keys()] # remove extraneous articles
print(len(articles))
# Out:
# 25

# %% [markdown]
# ## Types of articles
#
# By looking at the `class` attribute of all article tags, it looks like there are 3 main types of articles:
#
# * news-feed-story-package
# * news-now/news-feed-shortstop (sometimes with attached media has-media)
# * video-standalone/video
#
# We only care about the `news-feed-story-package` articles
#
# (Attributes can be reached within a soup object directly, for example article['class'] returns ['news-feed-item', 'news-feed-story-package'])

# %%
for art in articles:
    print('---'*30)
    print(art['class'])
    print(art.a['class'])
# Out:
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-feed-story-package']
# ['story-link']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-feed-story-package']
# ['story-link']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-now', 'news-feed-shortstop']
# ['btn-social', 'sm', 'icon-font-before', 'icon-facebook-solid-before', 'Shortstop']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-now', 'news-feed-shortstop']
# ['btn-social', 'sm', 'icon-font-before', 'icon-facebook-solid-before', 'Shortstop']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-now', 'news-feed-shortstop']
# ['btn-social', 'sm', 'icon-font-before', 'icon-facebook-solid-before', 'Shortstop']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-feed-story-package']
# ['story-link']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-now', 'news-feed-shortstop', 'has-media', 'module_bloom_behavior', '']
# ['btn-social', 'sm', 'icon-font-before', 'icon-facebook-solid-before', 'Shortstop']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-feed-story-package']
# ['story-link']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-feed-story-package']
# ['story-link']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-feed-story-package']
# ['story-link']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-now', 'news-feed-shortstop']
# ['btn-social', 'sm', 'icon-font-before', 'icon-facebook-solid-before', 'Shortstop']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'video-standalone', 'video']
# ['story-link']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'video-standalone', 'video']
# ['story-link']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-now', 'news-feed-shortstop']
# ['btn-social', 'sm', 'icon-font-before', 'icon-facebook-solid-before', 'Shortstop']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-feed-story-package']
# ['story-link']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-now', 'news-feed-shortstop']
# ['btn-social', 'sm', 'icon-font-before', 'icon-facebook-solid-before', 'Shortstop']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-now', 'news-feed-shortstop']
# ['btn-social', 'sm', 'icon-font-before', 'icon-facebook-solid-before', 'Shortstop']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-feed-story-package']
# ['story-link']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-feed-story-package']
# ['story-link']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-now', 'news-feed-shortstop']
# ['btn-social', 'sm', 'icon-font-before', 'icon-facebook-solid-before', 'Shortstop']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-feed-story-package']
# ['story-link']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-now', 'news-feed-shortstop']
# ['btn-social', 'sm', 'icon-font-before', 'icon-facebook-solid-before', 'Shortstop']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-feed-story-package']
# ['story-link']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-feed-story-package']
# ['story-link']
# ------------------------------------------------------------------------------------------
# ['news-feed-item', 'news-feed-story-package']
# ['story-link']

# %% [markdown]
# ---
#
# Lets find the desired info from the first article from the html below.
#
#
# Results:
# The attributes in the highest level `a` tag (class `story-link`) appear to have all the info we need, with the url in `data-popup-href`.  the `a` tag with class `realStory` includes the same incomplete `href` link, but isn't that useful.
#
#  The highest level `div` tag (with class `text-container no-headlines`) seems to contain any other possible useful info, but the only relevent info seems to be the text within the `span` tag with class `author`.

# %%
article = articles[0]
for child in article .children:
    print(child.name)
print()
pprint(article)
# Out:
# a
# figure
# div
#
# <article class="news-feed-item news-feed-story-package" data-id="buffalo-bills-32874">
#  <a class="story-link" data-id="buffalo-bills-32874" data-popup-href="http://espn.com/blog/buffalo-bills/post/_/id/32874/why-bills-lorenzo-alexander-stays-in-frigid-buffalo-in-offseason" data-sport="nfl" href="/blog/buffalo-bills/post/_/id/32874/why-bills-lorenzo-alexander-stays-in-frigid-buffalo-in-offseason" name="&amp;lpos=nfl:feed:xx:news">
#  </a>
#  <figure class="feed-item-figure ">
#   <div class="img-wrap">
#    <a data-mptype="image" data-sport="nfl" href="/blog/buffalo-bills/post/_/id/32874/why-bills-lorenzo-alexander-stays-in-frigid-buffalo-in-offseason" name="&amp;lpos=nfl:feed:xx:news">
#     <picture>
#      <source data-srcset="https://a4.espncdn.com/combiner/i?img=%2Fphoto%2F2019%2F0206%2Fr498444_1296x518_5%2D2.jpg&amp;w=375&amp;h=150&amp;scale=crop&amp;cquality=80&amp;location=origin, https://a4.espncdn.com/combiner/i?img=%2Fphoto%2F2019%2F0206%2Fr498444_1296x518_5%2D2.jpg&amp;w=768&amp;h=307&amp;scale=crop&amp;cquality=40&amp;location=origin&amp;format=jpg 2x" media="(max-width: 375px)">
#       <source data-srcset="https://a4.espncdn.com/combiner/i?img=%2Fphoto%2F2019%2F0206%2Fr498444_1296x518_5%2D2.jpg&amp;w=768&amp;h=307&amp;scale=crop&amp;cquality=80&amp;location=origin&amp;format=jpg, https://a4.espncdn.com/combiner/i?img=%2Fphoto%2F2019%2F0206%2Fr498444_1296x518_5%2D2.jpg&amp;w=1296&amp;h=518&amp;scale=crop&amp;cquality=40&amp;location=origin&amp;format=jpg 2x" media="(min-width: 376px)">
#        <img class=" lazyload" data-default-src="https://a.espncdn.com/photo/2019/0206/r498444_1296x518_5-2.jpg" data-image-container=".feed-item-figure"/>
#       </source>
#      </source>
#     </picture>
#    </a>
#   </div>
#   <span class="credit">
#    Rich Barnes/USA TODAY Sports
#   </span>
#  </figure>
#  <div class="text-container no-headlines">
#   <div class="item-info-wrap">
#    <div class="news-feed_item-meta ">
#     <span class="timestamp">
#      3d
#     </span>
#     <span class="author">
#      Mike Rodak
#     </span>
#    </div>
#    <h1>
#     <a class=" realStory" data-mptype="story" data-sport="nfl" href="/blog/buffalo-bills/post/_/id/32874/why-bills-lorenzo-alexander-stays-in-frigid-buffalo-in-offseason" name="&amp;lpos=nfl:feed:xx:news">
#      Why Bills' Lorenzo Alexander embraces the Buffalo winter
#     </a>
#    </h1>
#    <p>
#     While most players scurry south, the Bills' Lorenzo Alexander -- who recently re-signed for his 15th season -- sees the benefit of staying in Buffalo.
#    </p>
#   </div>
#  </div>
# </article>

# %%
article_info = {}

#if article['class'] = ['news-feed-item', 'news-feed-story-package']:
    
for child in article.children:
    if child.name == 'a':
        article_info['class'] = child['class'][0]
        article_info['data-id'] = child['data-id']
        article_info['url'] = child['data-popup-href']
        article_info['sport'] = child['data-sport']
    if child.name == 'div':
        for span in child.div.div.children: # should be a timestap and author span tag
            if 'timestamp' in span['class']: # Beautiful soup always makes the class a list (NOT a string)
                article_info['timestamp'] = span.string
            elif 'author' in span['class']:
                article_info['author'] = span.string

article_info
# Out:
# {'author': 'Mike Rodak',
#  'class': 'story-link',
#  'data-id': 'buffalo-bills-32874',
#  'sport': 'nfl',
#  'timestamp': '3d',
#  'url': 'http://espn.com/blog/buffalo-bills/post/_/id/32874/why-bills-lorenzo-alexander-stays-in-frigid-buffalo-in-offseason'}

# %% [markdown]
# ---
# Now that we have the logic set up for 1 page, lets get the full logic to extract all the articles

# %%
def extract_articles(soup, teamname): 
    articles = [art for art in soup.find_all('article') if 'data-id' in art.attrs.keys()]

    articles_list = []
    for article in articles:
        if 'news-feed-story-package' in article['class']: # should be ['news-feed-item', 'news-feed-story-package']
            article_info = {}
            article_info['teamname'] = teamname
            for child in article.children:
                if child.name == 'a':
                    article_info['class'] = child['class'][0]
                    article_info['data-id'] = child['data-id']
                    article_info['url'] = child['data-popup-href']
                    article_info['sport'] = child['data-sport']
                if child.name == 'div':
                    for span in child.div.div.children: # should be a timestap and author span tag
                        if 'timestamp' in span['class']: # Beautiful soup always makes the class a list (NOT a string)
                            article_info['timestamp'] = span.string
                        elif 'author' in span['class']:
                            article_info['author'] = span.string
                            
        articles_list.append(article_info)
    
    # convert list of dictionaries into dataframe
    df = pd.DataFrame(articles_list)
    return df

def get_df_from_teamname_link(link):
    teamname = link.split('/')[-1] # grab top link (ex 'buffalo-bills')
    html_page =  requests.get(link)
    soup = BeautifulSoup(html_page.content, 'lxml')
    df = extract_articles(soup, teamname)
    return df

# %%
link = "http://www.espn.com/nfl/team/_/name/buf/buffalo-bills"
df = get_df_from_teamname_link(link)
df
# Out:
#            author       class              data-id sport       teamname  \
# 0      Mike Rodak  story-link  buffalo-bills-32874   nfl  buffalo-bills
# 1   Jeremy Willis  story-link             25932328   nfl  buffalo-bills
# 2   Jeremy Willis  story-link             25932328   nfl  buffalo-bills
# 3   Jeremy Willis  story-link             25932328   nfl  buffalo-bills
# 4   Jeremy Willis  story-link             25932328   nfl  buffalo-bills
# 5   Bill Barnwell  story-link             25834281   nfl  buffalo-bills
# 6   Bill Barnwell  story-link             25834281   nfl  buffalo-bills
# 7            ESPN  story-link     nflnation-292685   nfl  buffalo-bills
# 8      Mike Rodak  story-link  buffalo-bills-32847   nfl  buffalo-bills
# 9      Mike Rodak  story-link  buffalo-bills-32849   nfl  buffalo-bills
# 10     Mike Rodak  story-link  buffalo-bills-32849   nfl  buffalo-bills
# 11     Mike Rodak  story-link  buffalo-bills-32849   nfl  buffalo-bills
# 12     Mike Rodak  story-link  buffalo-bills-32849   nfl  buffalo-bills
# 13     Mike Rodak  story-link  buffalo-bills-32849   nfl  buffalo-bills
# 14       ESPN.com  story-link             25780133   nfl  buffalo-bills
# 15       ESPN.com  story-link             25780133   nfl  buffalo-bills
# 16       ESPN.com  story-link             25780133   nfl  buffalo-bills
# 17     Mike Rodak  story-link             25777133   nfl  buffalo-bills
# 18       ESPN.com  story-link             25752270   nfl  buffalo-bills
# 19       ESPN.com  story-link             25752270   nfl  buffalo-bills
# 20     Mike Sando  story-link             25760521   nfl  buffalo-bills
# 21     Mike Sando  story-link             25760521   nfl  buffalo-bills
# 22   Jeff Legwold  story-link     nflnation-292403   nfl  buffalo-bills
# 23     Mike Rodak  story-link  buffalo-bills-32826   nfl  buffalo-bills
# 24           ESPN  story-link        afceast-88408   nfl  buffalo-bills
#
#    timestamp                                                url
# 0         3d  http://espn.com/blog/buffalo-bills/post/_/id/3...
# 1         4d  http://www.espn.com/nfl/story/_/id/25932328/nf...
# 2         4d  http://www.espn.com/nfl/story/_/id/25932328/nf...
# 3         4d  http://www.espn.com/nfl/story/_/id/25932328/nf...
# 4         4d  http://www.espn.com/nfl/story/_/id/25932328/nf...
# 5        12d  http://www.espn.com/nfl/story/_/id/25834281/pr...
# 6        12d  http://www.espn.com/nfl/story/_/id/25834281/pr...
# 7        16d  http://espn.com/blog/nflnation/post/_/id/29268...
# 8        16d  http://espn.com/blog/buffalo-bills/post/_/id/3...
# 9        17d  http://espn.com/blog/buffalo-bills/post/_/id/3...
# 10       17d  http://espn.com/blog/buffalo-bills/post/_/id/3...
# 11       17d  http://espn.com/blog/buffalo-bills/post/_/id/3...
# 12       17d  http://espn.com/blog/buffalo-bills/post/_/id/3...
# 13       17d  http://espn.com/blog/buffalo-bills/post/_/id/3...
# 14       24d  http://www.espn.com/nfl/story/_/id/25780133/of...
# 15       24d  http://www.espn.com/nfl/story/_/id/25780133/of...
# 16       24d  http://www.espn.com/nfl/story/_/id/25780133/of...
# 17       24d  http://www.espn.com/nfl/story/_/id/25777133/lo...
# 18       24d  http://www.espn.com/nfl/story/_/id/25752270/bi...
# 19       24d  http://www.espn.com/nfl/story/_/id/25752270/bi...
# 20       25d  http://insider.espn.com/nfl/insider/story/_/id...
# 21       25d  http://insider.espn.com/nfl/insider/story/_/id...
# 22       27d  http://espn.com/blog/nflnation/post/_/id/29240...
# 23       27d  http://espn.com/blog/buffalo-bills/post/_/id/3...
# 24       31d  http://espn.com/blog/afceast/post/_/id/88408/n...

# %% [markdown]
# ## Final Notes
#
# * timestamp doesn't seem very useful
# * data-id sees to have higher level tags for type of article
# * it looks like there are (many) duplicates (can be removed with df.drop_duplicates).
